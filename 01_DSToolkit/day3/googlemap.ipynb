# %%
import requests

api_key = "AIzaSyDsXz5N95ReR7xYPbkQBWcGX9I_9gnrtcQ"
address = "Sihltalerstrasse 190, 8135 Langnau am Albis, Switzerland"

geo_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}"
geo_data = requests.get(geo_url).json()

if geo_data['status'] == 'OK':
    loc = geo_data['results'][0]['geometry']['location']
    lat, lng = loc['lat'], loc['lng']
    print(f"📍 Coordinates: Latitude {lat}, Longitude {lng}")
else:
    print(f"Error: {geo_data['status']}")
