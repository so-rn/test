# %%
import requests

url = "https://motion.propulsion-home.ch/backend/api/auth/token/"
credentials = {
    "email": "soraan.mahmoudi@gmail.com", 
    "password": "data_science2021"
}

resp = requests.post(url, json=credentials)

# %%
print(f"Status Code: {resp.status_code}")
print(f"Response Body: {resp.json()}")
# Out:
# Status Code: 200
# ...

# %%
access_token = resp.json().get("access")
print(f"access_token: {access_token[:10]}...")
# Out:
# access_token: eyJhbGciOi...

# %%
users_url = "https://motion.propulsion-home.ch/backend/api/users/"
headers = {
    "Authorization": f"Bearer {access_token}"
}
user_response = requests.get(users_url, headers=headers)
print(f"Users Status Code: {user_response.status_code}")
# Out:
# Users Status Code: 200

# %%
user_list = user_response.json()
print(f"User List: {user_list}")
# Out:
# User List: {'count': 888, 'next': 'https://motion.propulsion-home.ch/backend/api/users/?limit=25&offset=25', 'previous': None, 'results': [{'id': 3111, 'email': 'dadefi8005@hupoi.com', 'first_name': 'Jana', 'last_name': 'Laula', 'username': 'Jaja', 'job': '', 'avatar': 'https://motion.propulsion-home.ch/media-files/Avatar_6.jpg', 'banner': None, 'location': 'Zurich, Switzerland', 'phone_number': '', 'about_me': 'A description of a person living in Zurich', 'things_user_likes': ['Coding'], 'logged_in_user_is_following': False, 'logged_in_user_is_friends': False, 'logged_in_user_is_rejected': False, 'logged_in_user_received_fr': False, 'logged_in_user_sent_fr': False, 'amount_of_posts': 0, 'amount_of_likes': 0, 'amount_of_friends': 3, 'amount_of_followers': 35, 'amount_following': 0}, {'id': 794, 'email': 'danielam@propulsionacademy.com', 'first_name': 'Daniel', 'last_name': 'Amaro', 'username': 'danielam@propulsionacademy.com', 'job': '', 'avatar': 'https://motion.propulsion-home.ch/m
# ...

# %%
actual_users = user_list.get('results', [])

print("--- User List ---")
for user in actual_users:
    first_name = user.get("first_name")
    last_name = user.get("last_name")
    user_id = user.get("id")
    user_email = user.get("email")
    
    print(f"ID: {user_id} | Name: {first_name} {last_name} | Email: {user_email}")
# Out:
# --- User List ---
# ID: 3111 | Name: Jana Laula | Email: dadefi8005@hupoi.com
# ID: 794 | Name: Daniel Amaro | Email: danielam@propulsionacademy.com
# ID: 2688 | Name: Gabor Menunni | Email: wqeilorcqihsqqfjhq@bbitq.com
# ID: 3615 | Name: Hristo Batch28 | Email: manog10418@avastu.com
# ID: 3182 | Name: Pekeno Poko | Email: pekono4843@mcenb.com
# ID: 1 | Name: Daniel Ermann | Email: danieler@propulsionacademy.com
# ID: 3382 | Name: Raphael Cordon | Email: satobag893@bizatop.com
# ID: 3648 | Name: emre kuzuc | Email: jadeveon.alexio@dockleafs.com
# ID: 3909 | Name: ojdsfhodh pdsjpsdj | Email: ghozmdksjhprhztiho@nbmbb.com
# ID: 3681 | Name: Jihye Chung | Email: livocak265@acuxi.com
# ID: 3467 | Name: Sehun Kim | Email: xeyan15346@mcuma.com
# ID: 3401 | Name: michael jackson | Email: mabino4431@fashlend.com
# ID: 2432 | Name: Klaus Taquito | Email: adm131213+001@gmail.com
# ID: 2880 | Name: Roger Gerox | Email: roxeg89122@tutoreve.com
# ...

# %%
print(f"Status: {send_response.status_code}")
print(f"Message: {send_response.text}")
# Out:
# Status: 200
# ...

# %%
target_id = 3591
send_url = f"https://motion.propulsion-home.ch/backend/api/social/friends/request/{target_id}/"
send_response = requests.post(send_url, headers=headers)
print(f"Friend Request Status Code: {send_response.status_code}")
# Out:
# Friend Request Status Code: 200

# %%
me_url = "https://motion.propulsion-home.ch/backend/api/users/me/"

me_response = requests.get(me_url, headers=headers)

if me_response.status_code == 200:
    my_data = me_response.json()
    my_id = my_data.get('id')
    print(f"Your ID: {my_id}")
    print(f"Your Username: {my_data.get('username')}")
else:
    print(f"Error: {me_response.status_code}")
# Out:
# Your ID: 4810
# Your Username: soraan.mahmoudi@gmail.com

# %%
for req in all_reqs:
    # Check if the status is Pending
    if req.get('status') == "P": 
        request_id = req.get('id')
        requester_info = req.get('requester')
        print(f"Request ID: {request_id} from {requester_info.get('username')}")
# Out:
# Request ID: 2150 from soraan.mahmoudi@gmail.com
# Request ID: 2152 from soraan.mahmoudi@gmail.com
# Request ID: 2153 from soraan.mahmoudi@gmail.com

# %%
#scripy darkjhast autmatic acc beshan
requests_url = "https://motion.propulsion-home.ch/backend/api/social/friends/requests/"
response = requests.get(requests_url, headers=headers)
all_requests = response.json().get('results', [])

print("Scanning for pending requests...")

for req in all_requests:
    if req.get('status') == "P":
        req_id = req.get('id')
        sender = req.get('requester').get('username')
        
        accept_url = f"https://motion.propulsion-home.ch/backend/api/social/friends/requests/{req_id}/"
        patch_response = requests.patch(accept_url, headers=headers, json={"status": "A"})
        
        if patch_response.status_code == 200:
            print(f"✅ Successfully accepted request from: {sender} (ID: {req_id})")
        else:
            print(f"❌ Failed to accept {req_id}. Error: {patch_response.status_code}")

print("--- Auto-Accept friend requests completed ---")
# Out:
# Scanning for pending requests...
# --- Auto-Accept friend requests completed ---

# %%
# list dostam 
friends_list_url = "https://motion.propulsion-home.ch/backend/api/social/friends/"

friends_response = requests.get(friends_list_url, headers=headers)

if friends_response.status_code == 200:
    friends_data = friends_response.json().get('results', [])
    print(f"Total Friends: {len(friends_data)}")
    print("--- Your Friends ---")
    for friend in friends_data:
        print(f"Name: {friend.get('first_name')} {friend.get('last_name')} | Username: {friend.get('username')}")
else:
    print(f"Error fetching friends: {friends_response.status_code}")
# Out:
# Total Friends: 3
# --- Your Friends ---
# Name: hebe hebe | Username: hebe
# Name: cedric kohler | Username: ckohler-constrcutor
# Name: Varantorn Weruwanarak | Username: varantorn.w@gmail.com

# %%
post_url = "https://motion.propulsion-home.ch/backend/api/social/posts/"

post_data = {"content": "Hi guys its my last post hihihihihi"}


post_response = requests.post(post_url, headers=headers, json=post_data)

if post_response.status_code == 201: 
    print("✅ Post created successfully!")
else:
    print(f"❌ Failed to post: {post_response.status_code}")
# Out:
# ✅ Post created successfully!

# %%
all_posts_url = "https://motion.propulsion-home.ch/backend/api/social/posts/"
all_posts_res = requests.get(all_posts_url, headers=headers)

print("--- Global Feed ---")
for post in all_posts_res.json().get('results', []):
    author = post.get('user', {}).get('username', 'Unknown')
    content = post.get('content')
    print(f"👤 {author}: {content}")
# Out:
# --- Global Feed ---
# 👤 soraan.mahmoudi@gmail.com: Hi guys its my last post hihihihihi
# 👤 soraan.mahmoudi@gmail.com: Hi guys its my last post hihihihihi
# 👤 python_course: Post created with the request module by xxx
# 👤 python_course: Post created with the request module by xxx
# 👤 python_course: Post created with the request module by Albin UPDATED twice!!!
# 👤 python_course: Post created with the request module by xxx
# 👤 python_course: Post created with the request module by xxx
# 👤 python_course: Post created with the request module by xxx
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# ...

# %%
all_posts_url = "https://motion.propulsion-home.ch/backend/api/social/posts/"

all_posts_response = requests.get(all_posts_url, headers=headers)

if all_posts_response.status_code == 200:
    posts_data = all_posts_response.json().get('results', [])
    print(f"--- Showing {len(posts_data)} Recent Posts ---")
    
    for post in posts_data:
  
        user = post.get('user', {})
        author_name = f"{user.get('first_name', '')} {user.get('last_name', '')}".strip() or user.get('username')
        content = post.get('content')
        
        print(f"👤 {author_name}: {content}")
        print("-" * 20)
else:
    print(f"❌ Could not fetch posts. Status: {all_posts_response.status_code}")
# Out:
# --- Showing 25 Recent Posts ---
# 👤 Karzan Mahmoudi: Hi guys its my last post hihihihihi
# --------------------
# 👤 Karzan Mahmoudi: Hi guys its my last post hihihihihi
# --------------------
# 👤 Solutions 2024: Post created with the request module by xxx
# --------------------
# 👤 Solutions 2024: Post created with the request module by xxx
# --------------------
# 👤 Solutions 2024: Post created with the request module by Albin UPDATED twice!!!
# --------------------
# 👤 Solutions 2024: Post created with the request module by xxx
# --------------------
# 👤 Solutions 2024: Post created with the request module by xxx
# --------------------
# 👤 Solutions 2024: Post created with the request module by xxx
# --------------------
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# --------------------
# 👤 juan.enciso.cv@gmail.com: List all the users first names, last names, id and email
# --------------------
# ...

# %%
# The URL for your own profile
profile_url = "https://motion.propulsion-home.ch/backend/api/users/me/"


updated_data = {
    "first_name": "SoRaaN",
    "last_name": "Mahmoudi"
}


profile_response = requests.patch(profile_url, headers=headers, json=updated_data)

if profile_response.status_code == 200:
    updated_info = profile_response.json()
    print("✅ Profile Updated Successfully!")
    print(f"New Name: {updated_info.get('first_name')} {updated_info.get('last_name')}")
else:
    print(f"❌ Failed to update profile. Status: {profile_response.status_code}")
    print(f"Error Message: {profile_response.text}")
# Out:
# ✅ Profile Updated Successfully!
# New Name: SoRaaN Mahmoudi
