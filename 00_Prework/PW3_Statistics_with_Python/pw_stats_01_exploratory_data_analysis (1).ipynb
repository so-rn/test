# %% [markdown]
# <center><img src=https://lh3.googleusercontent.com/d/1EmH3Jks5CpJy0zK3JbkvJZkeqWtVcxhB width=600></center>
#
# # Exploratory Data Analysis - A brief introduction
#
# In this tutorial you will get yourself familiar with general python tools for exploratory data analysis. We prepared examples on the most common data manipulations and plotting. After each new concept there are some exercises as well. So that you can practise what you've just learned.
#
#
# The exercises are annotated as follows:
# ---------------------------------------
#
# ### Exercise
#
# text of the task

# %%
# your code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')
starwars.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75.0        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32.0        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136.0       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49.0      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %% [markdown]
# ---------------------------------------
#
# You need to provide your code on the basis of what you've just learned. Or, if you know another way, you are welcome to be creative. All the tasks are possible to solve with just scrolling up the tutorial and reading carefully. But you can google or read the  literature provided if you want to build something extra. Well, let's start our Exploratory Data Analysis (EDA) journey!
#
#
# # Getting Started with EDA
#
#
# ## Information
#
# One of the most popular software tool stacks for data science is __PyData__, a collection of software packages and tools within Python itself. We already know by now that Python is one of the most popular languages for data science, largely thanks to its excellent developer eco-system and variety of powerful open-source tools and packages.
#
# ![](https://i.imgur.com/2yfeMP0.png)
#
# The most popular packages in the PyData stack which you will end up using throughout this course and even in your journey and career as a Data Scientist will include the following:
#
# - NumPy: A popular linear algebra library for fast numeric computations on vectors and matrices in Python.
# - SciPy: A popular scientific computing library which has several mathematical and statistical functions including, distributions, statistical tests, integration, differentiation and optimization, which can be used with NumPy objects.
# - Pandas: Builds on NumPy and provides tabular data structures like dataframes which can be used to work with tabular data.
# - Scikit-learn: The most popular Python machine learning library, includes many popular models to perform predictive analytics, modeling, diagnostics as well as data processing and wrangling.
# - StatsModels: Similar to scikit-learn, aimed at performing descriptive and inferential statistics.
# - Matplotlib: A popular generic plotting library including histograms, line, bar, and scatter plots. Can also be accessed through pandas.
# - Seaborn: A visualization library building on matplotlib, including plotting of distributions and heatmaps with better aesthetics and visuals.
#
#
# ## Installation and Loading
#
# The easiest option is to use [Anaconda](https://www.anaconda.com/products/individual) to download and install the necessary python distribution for your computer's operating system and it comes pre-installed with all necessary packages.
#
# However if you want to install specific packages only you can use `pip install <package_name>` or `conda install <package_name>`

# %% [markdown]
# Once we installed the packages it is time to load it. Let's start with "pandas".

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# Now we are ready to explore the data
#
# # Load the data
#
# We start with loading the data and then analyze it with `pandas` and Python to subset, slice, sort, group and visualize!
#
# In this tutorial, we'll be exploring the 'Star Wars' dataset, where each observation is a character and each variable is a feature such as height, mass or hair_color.
#
# To check out the first several observations of your dataframe, we first need to read in the file. For this we use the `pandas` [`read_csv`](https://pandas.pydata.org/pandas-docs/dev/reference/api/pandas.read_csv.html) function. We always recommend checking the documentation which usually has a wealth of information available about specific functions and their roles.

# %%
df = pd.read_csv('data/pw_stats_01_star_wars.csv')

# %% [markdown]
# To see the type of the variable you just created you can use the `type` function as depicted below

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# To view your data you can just type in the variable name as follows

# %%
df
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species
# 0       19BBY    male  Tatooine   Human
# 1      112BBY     NaN  Tatooine   Droid
# 2       33BBY     NaN     Naboo   Droid
# 3     41.9BBY    male  Tatooine   Human
# 4       19BBY  female  Alderaan   Human
# ..        ...     ...       ...     ...
# 82        NaN  female       NaN   Human
# 83        NaN    male       NaN   Human
# 84        NaN    none       NaN   Droid
# 85        NaN  female       NaN     NaN
# 86      46BBY  female     Naboo   Human
#
# [87 rows x 10 columns]

# %% [markdown]
# Note: the output of this operation is quite big.
#
# To view the first few rows of the dataframe you can use the `head()` function

# %%
df.head()
# Out:
#              name  height   mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0   77.0      blond         fair      blue      19BBY
# 1           C-3PO   167.0   75.0        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0   32.0        NaN  white, blue       red      33BBY
# 3     Darth Vader   202.0  136.0       none        white    yellow    41.9BBY
# 4     Leia Organa   150.0   49.0      brown        light     brown      19BBY
#
#    gender homeworld species
# 0    male  Tatooine   Human
# 1     NaN  Tatooine   Droid
# 2     NaN     Naboo   Droid
# 3    male  Tatooine   Human
# 4  female  Alderaan   Human

# %% [markdown]
# To view the last few rows similarly you can use the `tail()` function

# %%
df.tail()
# Out:
#               name  height  mass hair_color skin_color eye_color birth_year  \
# 82             Rey     NaN   NaN      brown      light     hazel        NaN
# 83     Poe Dameron     NaN   NaN      brown      light     brown        NaN
# 84             BB8     NaN   NaN       none       none     black        NaN
# 85  Captain Phasma     NaN   NaN        NaN        NaN       NaN        NaN
# 86   Padmé Amidala   165.0  45.0      brown      light     brown      46BBY
#
#     gender homeworld species
# 82  female       NaN   Human
# 83    male       NaN   Human
# 84    none       NaN   Droid
# 85  female       NaN     NaN
# 86  female     Naboo   Human

# %% [markdown]
# To get a quick check on the dimensions of the dataframe you can use the `shape` attribute

# %%
df.shape
# Out:
# (87, 10)

# %% [markdown]
# Looks like we have 87 rows and 10 columns in our dataset

# %% [markdown]
# You can also get detailed information about each column of our dataframe using the `info()` function as follows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        87 non-null     object
#  1   height      81 non-null     float64
#  2   mass        59 non-null     float64
#  3   hair_color  81 non-null     object
#  4   skin_color  85 non-null     object
#  5   eye_color   84 non-null     object
#  6   birth_year  43 non-null     object
#  7   gender      84 non-null     object
#  8   homeworld   77 non-null     object
#  9   species     82 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 6.9+ KB

# %% [markdown]
# Looks like there are quite a number of columns with missing values!

# %% [markdown]
# # Data Wrangling with "pandas"
#
# Now it's time to explore your data and get some initial insight into the dataset. You'll be using __`pandas`__ functions and operations in this section.
#
# Let's assume that you want to choose a particular set of observations, say, those for which the "species" was 'Droid'.
#
# ## To select rows based on condition
#
# Select all rows where species is Droid:

# %%
df['species'] == 'Droid'
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
#       ...
# 82    False
# 83    False
# 84     True
# 85    False
# 86    False
# Name: species, Length: 87, dtype: bool

# %% [markdown]
# The above condition shows us for which rows the `species` column has the value 'Droid' (identified by `True`) and for which rows it has some other value (identified by `False`). We can then use the following subset expression to only show the rows where `species` is `Droid`

# %%
df[df['species'] == 'Droid']
# Out:
#      name  height   mass hair_color   skin_color eye_color birth_year gender  \
# 1   C-3PO   167.0   75.0        NaN         gold    yellow     112BBY    NaN
# 2   R2-D2    96.0   32.0        NaN  white, blue       red      33BBY    NaN
# 7   R5-D4    97.0   32.0        NaN   white, red       red        NaN    NaN
# 21  IG-88   200.0  140.0       none        metal       red      15BBY   none
# 84    BB8     NaN    NaN       none         none     black        NaN   none
#
#    homeworld species
# 1   Tatooine   Droid
# 2      Naboo   Droid
# 7   Tatooine   Droid
# 21       NaN   Droid
# 84       NaN   Droid

# %% [markdown]
# Now select all rows where species is not Droid

# %%
df[df['species'] != 'Droid']
# Out:
#                   name  height   mass   hair_color skin_color eye_color  \
# 0       Luke Skywalker   172.0   77.0        blond       fair      blue
# 3          Darth Vader   202.0  136.0         none      white    yellow
# 4          Leia Organa   150.0   49.0        brown      light     brown
# 5            Owen Lars   178.0  120.0  brown, grey      light      blue
# 6   Beru Whitesun lars   165.0   75.0        brown      light      blue
# ..                 ...     ...    ...          ...        ...       ...
# 81                Finn     NaN    NaN        black       dark      dark
# 82                 Rey     NaN    NaN        brown      light     hazel
# 83         Poe Dameron     NaN    NaN        brown      light     brown
# 85      Captain Phasma     NaN    NaN          NaN        NaN       NaN
# 86       Padmé Amidala   165.0   45.0        brown      light     brown
#
#    birth_year  gender homeworld species
# 0       19BBY    male  Tatooine   Human
# 3     41.9BBY    male  Tatooine   Human
# 4       19BBY  female  Alderaan   Human
# 5       52BBY    male  Tatooine   Human
# 6       47BBY  female  Tatooine   Human
# ..        ...     ...       ...     ...
# 81        NaN    male       NaN   Human
# 82        NaN  female       NaN   Human
# 83        NaN    male       NaN   Human
# 85        NaN  female       NaN     NaN
# 86      46BBY  female     Naboo   Human
#
# [82 rows x 10 columns]

# %% [markdown]
# The above can also be done in another way using the `~` operator as follows.

# %%
df[~(df['species'] == 'Droid')]
# Out:
#                   name  height   mass   hair_color skin_color eye_color  \
# 0       Luke Skywalker   172.0   77.0        blond       fair      blue
# 3          Darth Vader   202.0  136.0         none      white    yellow
# 4          Leia Organa   150.0   49.0        brown      light     brown
# 5            Owen Lars   178.0  120.0  brown, grey      light      blue
# 6   Beru Whitesun lars   165.0   75.0        brown      light      blue
# ..                 ...     ...    ...          ...        ...       ...
# 81                Finn     NaN    NaN        black       dark      dark
# 82                 Rey     NaN    NaN        brown      light     hazel
# 83         Poe Dameron     NaN    NaN        brown      light     brown
# 85      Captain Phasma     NaN    NaN          NaN        NaN       NaN
# 86       Padmé Amidala   165.0   45.0        brown      light     brown
#
#    birth_year  gender homeworld species
# 0       19BBY    male  Tatooine   Human
# 3     41.9BBY    male  Tatooine   Human
# 4       19BBY  female  Alderaan   Human
# 5       52BBY    male  Tatooine   Human
# 6       47BBY  female  Tatooine   Human
# ..        ...     ...       ...     ...
# 81        NaN    male       NaN   Human
# 82        NaN  female       NaN   Human
# 83        NaN    male       NaN   Human
# 85        NaN  female       NaN     NaN
# 86      46BBY  female     Naboo   Human
#
# [82 rows x 10 columns]

# %% [markdown]
# ### Exercise
#
# Find species which are human

# %%
#your code here
humans = starwars[starwars['species'] == 'Human']
print(humans[['name', 'species']].head())
print(f"Total number of humans: {len(humans)}")
# Out:
#                  name species
# 0      Luke Skywalker   Human
# 3         Darth Vader   Human
# 4         Leia Organa   Human
# 5           Owen Lars   Human
# 6  Beru Whitesun lars   Human
# Total number of humans: 35

# %% [markdown]
# ## To select rows based on positions
#
# You can use the `iloc` functionality to select specific rows based on index (position).
#
# Select the first three rows of the dataframe

# %%
df.iloc[0:3, :]
# Out:
#              name  height  mass hair_color   skin_color eye_color birth_year  \
# 0  Luke Skywalker   172.0  77.0      blond         fair      blue      19BBY
# 1           C-3PO   167.0  75.0        NaN         gold    yellow     112BBY
# 2           R2-D2    96.0  32.0        NaN  white, blue       red      33BBY
#
#   gender homeworld species
# 0   male  Tatooine   Human
# 1    NaN  Tatooine   Droid
# 2    NaN     Naboo   Droid

# %% [markdown]
# Select rows 10, 15 and 17 of the dataframe

# %%
df.iloc[[10, 15, 17], :]
# Out:
#                      name  height    mass hair_color        skin_color  \
# 10       Anakin Skywalker   188.0    84.0      blond              fair
# 15  Jabba Desilijic Tiure   175.0  1358.0        NaN  green-tan, brown
# 17       Jek Tono Porkins   180.0   110.0      brown              fair
#
#    eye_color birth_year         gender   homeworld species
# 10      blue    41.9BBY           male    Tatooine   Human
# 15    orange     600BBY  hermaphrodite   Nal Hutta    Hutt
# 17      blue        NaN           male  Bestine IV   Human

# %% [markdown]
# ### Exercise
#
# Select rows 70 and 75 of the dataframe and display them

# %%
#your code here
starwars.iloc[[70, 75]]
# Out:
#           name  height  mass hair_color        skin_color eye_color  \
# 70  Jocasta Nu   167.0   NaN      white              fair      blue
# 75    Shaak Ti   178.0  57.0       none  red, blue, white     black
#
#    birth_year  gender  homeworld  species
# 70        NaN  female  Coruscant    Human
# 75        NaN  female      Shili  Togruta

# %% [markdown]
# ## To select columns based on position
#
# Select the column names based on the column number using `iloc`
#
# Show the first three columns of the dataframe

# %%
df.iloc[:, 0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.iloc[:, 0:3]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Show columns 0, 3 and 6 of the dataframe

# %%
df.iloc[:, [0, 3, 6]]
# Out:
#               name hair_color birth_year
# 0   Luke Skywalker      blond      19BBY
# 1            C-3PO        NaN     112BBY
# 2            R2-D2        NaN      33BBY
# 3      Darth Vader       none    41.9BBY
# 4      Leia Organa      brown      19BBY
# ..             ...        ...        ...
# 82             Rey      brown        NaN
# 83     Poe Dameron      brown        NaN
# 84             BB8       none        NaN
# 85  Captain Phasma        NaN        NaN
# 86   Padmé Amidala      brown      46BBY
#
# [87 rows x 3 columns]

# %% [markdown]
# ### Exercise
#
# Show columns 0 and 5 of the dataframe and display them

# %%
#your code here
starwars.iloc[:, [0, 5]]
# Out:
#               name eye_color
# 0   Luke Skywalker      blue
# 1            C-3PO    yellow
# 2            R2-D2       red
# 3      Darth Vader    yellow
# 4      Leia Organa     brown
# ..             ...       ...
# 82             Rey     hazel
# 83     Poe Dameron     brown
# 84             BB8     black
# 85  Captain Phasma       NaN
# 86   Padmé Amidala     brown
#
# [87 rows x 2 columns]

# %% [markdown]
# ## To select columns based on name
#
# Select the column names based on the column number using `loc`
#
# Show the columns, `name` and `hair_color` of the dataframe

# %%
df.loc[:, ['name', 'hair_color']]
# Out:
#               name hair_color
# 0   Luke Skywalker      blond
# 1            C-3PO        NaN
# 2            R2-D2        NaN
# 3      Darth Vader       none
# 4      Leia Organa      brown
# ..             ...        ...
# 82             Rey      brown
# 83     Poe Dameron      brown
# 84             BB8       none
# 85  Captain Phasma        NaN
# 86   Padmé Amidala      brown
#
# [87 rows x 2 columns]

# %% [markdown]
# Alternatively you can also use the following

# %%
df[['name', 'hair_color']]
# Out:
#               name hair_color
# 0   Luke Skywalker      blond
# 1            C-3PO        NaN
# 2            R2-D2        NaN
# 3      Darth Vader       none
# 4      Leia Organa      brown
# ..             ...        ...
# 82             Rey      brown
# 83     Poe Dameron      brown
# 84             BB8       none
# 85  Captain Phasma        NaN
# 86   Padmé Amidala      brown
#
# [87 rows x 2 columns]

# %% [markdown]
# ## To create new variables
#
# Create a new column 'bmi' based on two other columns 'mass' and 'height'
#
# bmi = mass / height ^ 2 (metres squared)

# %% [markdown]
# Let's check the data types for the columns

# %%
df.dtypes
# Out:
# name           object
# height        float64
# mass          float64
# hair_color     object
# skin_color     object
# eye_color      object
# birth_year     object
# gender         object
# homeworld      object
# species        object
# dtype: object

# %%
df['bmi'] = df['mass'] / (df['height'] / 100) ** 2

# %%
df
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species        bmi
# 0       19BBY    male  Tatooine   Human  26.027582
# 1      112BBY     NaN  Tatooine   Droid  26.892323
# 2       33BBY     NaN     Naboo   Droid  34.722222
# 3     41.9BBY    male  Tatooine   Human  33.330066
# 4       19BBY  female  Alderaan   Human  21.777778
# ..        ...     ...       ...     ...        ...
# 82        NaN  female       NaN   Human        NaN
# 83        NaN    male       NaN   Human        NaN
# 84        NaN    none       NaN   Droid        NaN
# 85        NaN  female       NaN     NaN        NaN
# 86      46BBY  female     Naboo   Human  16.528926
#
# [87 rows x 11 columns]

# %% [markdown]
# Let's make it look a bit better by round off the decimal places

# %%
df['bmi'] = round(df['bmi'], 2)
df
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species    bmi
# 0       19BBY    male  Tatooine   Human  26.03
# 1      112BBY     NaN  Tatooine   Droid  26.89
# 2       33BBY     NaN     Naboo   Droid  34.72
# 3     41.9BBY    male  Tatooine   Human  33.33
# 4       19BBY  female  Alderaan   Human  21.78
# ..        ...     ...       ...     ...    ...
# 82        NaN  female       NaN   Human    NaN
# 83        NaN    male       NaN   Human    NaN
# 84        NaN    none       NaN   Droid    NaN
# 85        NaN  female       NaN     NaN    NaN
# 86      46BBY  female     Naboo   Human  16.53
#
# [87 rows x 11 columns]

# %% [markdown]
# A BMI of 25 or more is 'overweight' and less than that is 'healthy'. Let's create a new column `bmi_health` to show this.
#
# We can use a lambda function along with `apply()` to perform this operation and transformation

# %%
df['bmi'].apply(lambda value: 'overweight' if value >= 25 else 'healthy')
# Out:
# 0     overweight
# 1     overweight
# 2     overweight
# 3     overweight
# 4        healthy
#          ...
# 82       healthy
# 83       healthy
# 84       healthy
# 85       healthy
# 86       healthy
# Name: bmi, Length: 87, dtype: object

# %% [markdown]
# Let's assign this to the new column now

# %%
df['bmi_health'] = df['bmi'].apply(lambda value: 'overweight' if value >= 25 else 'healthy')
df
# Out:
#               name  height   mass hair_color   skin_color eye_color  \
# 0   Luke Skywalker   172.0   77.0      blond         fair      blue
# 1            C-3PO   167.0   75.0        NaN         gold    yellow
# 2            R2-D2    96.0   32.0        NaN  white, blue       red
# 3      Darth Vader   202.0  136.0       none        white    yellow
# 4      Leia Organa   150.0   49.0      brown        light     brown
# ..             ...     ...    ...        ...          ...       ...
# 82             Rey     NaN    NaN      brown        light     hazel
# 83     Poe Dameron     NaN    NaN      brown        light     brown
# 84             BB8     NaN    NaN       none         none     black
# 85  Captain Phasma     NaN    NaN        NaN          NaN       NaN
# 86   Padmé Amidala   165.0   45.0      brown        light     brown
#
#    birth_year  gender homeworld species    bmi  bmi_health
# 0       19BBY    male  Tatooine   Human  26.03  overweight
# 1      112BBY     NaN  Tatooine   Droid  26.89  overweight
# 2       33BBY     NaN     Naboo   Droid  34.72  overweight
# 3     41.9BBY    male  Tatooine   Human  33.33  overweight
# 4       19BBY  female  Alderaan   Human  21.78     healthy
# ..        ...     ...       ...     ...    ...         ...
# 82        NaN  female       NaN   Human    NaN     healthy
# 83        NaN    male       NaN   Human    NaN     healthy
# 84        NaN    none       NaN   Droid    NaN     healthy
# 85        NaN  female       NaN     NaN    NaN     healthy
# 86      46BBY  female     Naboo   Human  16.53     healthy
#
# [87 rows x 12 columns]

# %% [markdown]
# ## Chaining several operations
#
# You can also chain multiple functions and operations in `pandas` as follows

# %%
df['bmi_health_new'] = (
                        (round((df['mass'] / (df['height'] / 100) ** 2), 2))
                        .apply(lambda value: 'overweight' if value >= 25 else 'healthy')
                       )
df[['name', 'bmi', 'bmi_health', 'bmi_health_new']]
# Out:
#               name    bmi  bmi_health bmi_health_new
# 0   Luke Skywalker  26.03  overweight     overweight
# 1            C-3PO  26.89  overweight     overweight
# 2            R2-D2  34.72  overweight     overweight
# 3      Darth Vader  33.33  overweight     overweight
# 4      Leia Organa  21.78     healthy        healthy
# ..             ...    ...         ...            ...
# 82             Rey    NaN     healthy        healthy
# 83     Poe Dameron    NaN     healthy        healthy
# 84             BB8    NaN     healthy        healthy
# 85  Captain Phasma    NaN     healthy        healthy
# 86   Padmé Amidala  16.53     healthy        healthy
#
# [87 rows x 4 columns]

# %% [markdown]
# ### Exercise
#
# Create a new column `height_qual` which should have the value `tall` if `height` is more than or equal to 180 else it should be `not tall`

# %%
#your code here
starwars['height_qual'] = starwars['height'].apply(lambda x: 'tall' if x >= 180 else 'not tall')
starwars[['name', 'height', 'height_qual']].head()
# Out:
#              name  height height_qual
# 0  Luke Skywalker   172.0    not tall
# 1           C-3PO   167.0    not tall
# 2           R2-D2    96.0    not tall
# 3     Darth Vader   202.0        tall
# 4     Leia Organa   150.0    not tall

# %% [markdown]
# ## To sort values in the dataframe
#
# Sort values by descending mass:

# %%
df.sort_values(by=['mass'], ascending=False).head(10)
# Out:
#                      name  height    mass   hair_color        skin_color  \
# 15  Jabba Desilijic Tiure   175.0  1358.0          NaN  green-tan, brown
# 76               Grievous   216.0   159.0         none      brown, white
# 21                  IG-88   200.0   140.0         none             metal
# 3             Darth Vader   202.0   136.0         none             white
# 77                Tarfful   234.0   136.0        brown             brown
# 5               Owen Lars   178.0   120.0  brown, grey             light
# 22                  Bossk   190.0   113.0         none             green
# 12              Chewbacca   228.0   112.0        brown               NaN
# 17       Jek Tono Porkins   180.0   110.0        brown              fair
# 67        Dexter Jettster   198.0   102.0         none             brown
#
#         eye_color birth_year         gender   homeworld     species     bmi  \
# 15         orange     600BBY  hermaphrodite   Nal Hutta        Hutt  443.43
# 76  green, yellow        NaN           male       Kalee     Kaleesh   34.08
# 21            red      15BBY           none         NaN       Droid   35.00
# 3          yellow    41.9BBY           male    Tatooine       Human   33.33
# 77           blue        NaN           male    Kashyyyk     Wookiee   24.84
# 5            blue      52BBY           male    Tatooine       Human   37.87
# 22            red      53BBY           male   Trandosha  Trandoshan   31.30
# 12           blue     200BBY           male    Kashyyyk     Wookiee   21.55
# 17           blue        NaN           male  Bestine IV       Human   33.95
# 67         yellow        NaN           male        Ojom    Besalisk   26.02
#
#     bmi_health bmi_health_new
# 15  overweight     overweight
# 76  overweight     overweight
# 21  overweight     overweight
# 3   overweight     overweight
# 77     healthy        healthy
# 5   overweight     overweight
# 22  overweight     overweight
# 12     healthy        healthy
# 17  overweight     overweight
# 67  overweight     overweight

# %% [markdown]
# ### Exercise
# Show 10 shortest characters

# %%
#your code here
starwars.nsmallest(10, 'height')[['name', 'height']]
# Out:
#                      name  height
# 18                   Yoda    66.0
# 71          Ratts Tyerell    79.0
# 28  Wicket Systri Warrick    88.0
# 44               Dud Bolt    94.0
# 2                   R2-D2    96.0
# 72                 R4-P17    96.0
# 7                   R5-D4    97.0
# 38                Sebulba   112.0
# 45                Gasgano   122.0
# 37                  Watto   137.0

# %% [markdown]
# ## To summarize data by specific groupings, use groupby()
#
# Summarise the number of observations and the average mass for each species:

# %%
df.groupby(by=['species']).agg({
    'mass': 'mean',
    'species': 'count'
}).rename(columns={
    'mass': 'mean_mass',
    'species': 'count'
})
# Out:
#                   mean_mass  count
# species
# Aleena            15.000000      1
# Besalisk         102.000000      1
# Cerean            82.000000      1
# Chagrian                NaN      1
# Clawdite          55.000000      1
# Droid             69.750000      5
# Dug               40.000000      1
# Ewok              20.000000      1
# Geonosian         80.000000      1
# Gungan            74.000000      3
# Human             82.781818     35
# Hutt            1358.000000      1
# Iktotchi                NaN      1
# Kaleesh          159.000000      1
# Kaminoan          88.000000      2
# Kel Dor           80.000000      1
# Mirialan          53.100000      2
# Mon Calamari      83.000000      1
# Muun                    NaN      1
# Nautolan          87.000000      1
# Neimodian         90.000000      1
# Pau'an            80.000000      1
# Quermian                NaN      1
# Rodian            74.000000      1
# Skakoan           48.000000      1
# Sullustan         68.000000      1
# Tholothian        50.000000      1
# Togruta           57.000000      1
# Toong             65.000000      1
# Toydarian               NaN      1
# Trandoshan       113.000000      1
# Twi'lek           55.000000      2
# Vulptereen        45.000000      1
# Wookiee          124.000000      2
# Xexto                   NaN      1
# Yoda's species    17.000000      1
# Zabrak            80.000000      2

# %% [markdown]
# Show the top three species in our dataset

# %%
result = df.groupby(by=['species']).agg({
    'mass': 'mean',
    'species': 'count'
}).rename(columns={
    'mass': 'mean_mass',
    'species': 'count'
})

result.sort_values(by=['count'], ascending=False).head(3)
# Out:
#          mean_mass  count
# species
# Human    82.781818     35
# Droid    69.750000      5
# Gungan   74.000000      3

# %% [markdown]
# ### Exercise
# In which planet of origin (homeworld) are the tallest inhabitants on average?

# %%
#your code here
tallest_homeworlds = starwars.groupby('homeworld')['height'].mean().sort_values(ascending=False)
print(tallest_homeworlds.head(1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #your code here
# ----> 2 tallest_homeworlds = starwars.groupby('homeworld')['height'].mean().sort_values(ascending=False)
#       3 print(tallest_homeworlds.head(1))
#
# NameError: name 'starwars' is not defined

# %% [markdown]
# ## Long chain
#
# Choose the tallest (> 175) & heaviest (> 100) characters,
# group them by homeworld and species,
# show their average height and mass

# %%
result = df[(df['height'] > 175) & (df['mass'] > 100)]
result
# Out:
#                 name  height   mass   hair_color    skin_color      eye_color  \
# 3        Darth Vader   202.0  136.0         none         white         yellow
# 5          Owen Lars   178.0  120.0  brown, grey         light           blue
# 12         Chewbacca   228.0  112.0        brown           NaN           blue
# 17  Jek Tono Porkins   180.0  110.0        brown          fair           blue
# 21             IG-88   200.0  140.0         none         metal            red
# 22             Bossk   190.0  113.0         none         green            red
# 67   Dexter Jettster   198.0  102.0         none         brown         yellow
# 76          Grievous   216.0  159.0         none  brown, white  green, yellow
# 77           Tarfful   234.0  136.0        brown         brown           blue
#
#    birth_year gender   homeworld     species    bmi  bmi_health bmi_health_new
# 3     41.9BBY   male    Tatooine       Human  33.33  overweight     overweight
# 5       52BBY   male    Tatooine       Human  37.87  overweight     overweight
# 12     200BBY   male    Kashyyyk     Wookiee  21.55     healthy        healthy
# 17        NaN   male  Bestine IV       Human  33.95  overweight     overweight
# 21      15BBY   none         NaN       Droid  35.00  overweight     overweight
# 22      53BBY   male   Trandosha  Trandoshan  31.30  overweight     overweight
# 67        NaN   male        Ojom    Besalisk  26.02  overweight     overweight
# 76        NaN   male       Kalee     Kaleesh  34.08  overweight     overweight
# 77        NaN   male    Kashyyyk     Wookiee  24.84     healthy        healthy

# %%
result.groupby(by=['homeworld', 'species'])

# %%
result = result.groupby(by=['homeworld', 'species']).agg({
    'height': 'mean',
    'mass': 'mean'
})

result
# Out:
#                        height   mass
# homeworld  species
# Bestine IV Human        180.0  110.0
# Kalee      Kaleesh      216.0  159.0
# Kashyyyk   Wookiee      231.0  124.0
# Ojom       Besalisk     198.0  102.0
# Tatooine   Human        190.0  128.0
# Trandosha  Trandoshan   190.0  113.0

# %%
result = result.rename(columns={
    'height': 'mean_height',
    'mass': 'mean_mass'
})

result
# Out:
#                        mean_height  mean_mass
# homeworld  species
# Bestine IV Human             180.0      110.0
# Kalee      Kaleesh           216.0      159.0
# Kashyyyk   Wookiee           231.0      124.0
# Ojom       Besalisk          198.0      102.0
# Tatooine   Human             190.0      128.0
# Trandosha  Trandoshan        190.0      113.0

# %% [markdown]
# Chain all the above together!

# %%
(df[(df['height'] > 175) & (df['mass'] > 100)]
   .groupby(by=['homeworld', 'species'])
   .agg({
       'height': 'mean',
       'mass': 'mean'
    })
   .rename(columns={
       'height': 'mean_height',
       'mass': 'mean_mass'
    })
)
# Out:
#                        mean_height  mean_mass
# homeworld  species
# Bestine IV Human             180.0      110.0
# Kalee      Kaleesh           216.0      159.0
# Kashyyyk   Wookiee           231.0      124.0
# Ojom       Besalisk          198.0      102.0
# Tatooine   Human             190.0      128.0
# Trandosha  Trandoshan        190.0      113.0

# %% [markdown]
# ### Exercise
#
# Choose the people who have blue eyes,
# group them by homeworld and species,
# show their average height and mass

# %%
#your code here
starwars[starwars['eye_color'] == 'blue'].groupby(['homeworld', 'species'])[['height', 'mass']].mean()
# Out:
#                        height   mass
# homeworld  species
# Bespin     Human        175.0   79.0
# Bestine IV Human        180.0  110.0
# Champala   Chagrian     196.0    NaN
# Chandrila  Human        150.0    NaN
# Coruscant  Human        168.5    NaN
#            Tholothian   184.0   50.0
# Eriadu     Human        180.0    NaN
# Kashyyyk   Wookiee      231.0  124.0
# Mirial     Mirialan     168.0   53.1
# Tatooine   Human        177.2   89.0

# %% [markdown]
# # Plotting your data
#
# To plot your data there are several libraries including `matplotlib` and `seaborn` which you will also be introduced to later on in the course. Here we will use the basic plotting functionality of `pandas` itself.

# %% [markdown]
# ##  Barplot of gender
#
# First let's plot a barplot of 'gender' to see how many of them were in the movie.

# %%
df['gender'].value_counts()
# Out:
# male             62
# female           19
# none              2
# hermaphrodite     1
# Name: gender, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar');

# %% [markdown]
# From the above plot, you can tell that there were about 60 men and 20 women involved in action,
# as well as 1 hermaphrodite and probably 2 free from gender
#
# ## Scatter plot of mass vs height
#
# Now it's time for some scatter plots. Is the height of characters correlated with the mass?
#
# For scatter plot we need two variables : x and y. And we need to add a scatter layer to our plot.

# %%
df.plot.scatter(x='mass', y='height');

# %% [markdown]
# It seems that they are correlated, but it is hard to tell more precise, because we have an outlier!
# In this situation we can do 2 things:
#
#  1) Remove the outlier if it is an error (for example, if it does not represent our population)
#
#  2) investigate further, what is so special about this outlier. Is it a real character or an error of some sort
#
# ### Without outlier
# 1) Let's check the plot without outlier
#
# Adding a layer xlim() we set a limit to our x variable (which is 'mass' in our case), so the outlier is not shown [we use matplotlib for this]
#
# Note: How to detect outliers with a quantile function you will learn during the course

# %%
import matplotlib.pyplot as plt

df.plot.scatter(x='mass', y='height')
plt.xlim([0, 200]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df.plot.scatter(x='mass', y='height')
#       4 plt.xlim([0, 200]);
#
# NameError: name 'df' is not defined

# %% [markdown]
# yes, it seems that we have a correlation between mass and height!
#
# ### With outlier
#
# 2) Let's take a closer look at the outlier. Well, who it might be?

# %%
outlier = df[df['mass'] > 1000]
outlier
# Out:
#                      name  height    mass hair_color        skin_color  \
# 15  Jabba Desilijic Tiure   175.0  1358.0        NaN  green-tan, brown
#
#    eye_color birth_year         gender  homeworld species     bmi  bmi_health  \
# 15    orange     600BBY  hermaphrodite  Nal Hutta    Hutt  443.43  overweight
#
#    bmi_health_new
# 15     overweight

# %%
outlier_mass = outlier['mass'].values[0]
outlier_height = outlier['height'].values[0]
outlier_name = outlier['name'].values[0]

# %%
fig, ax = plt.subplots()
df.plot.scatter(x='mass', y='height', ax=ax)
ax.text(outlier_mass, outlier_height, outlier_name);

# %% [markdown]
# Well, there is no surprise that Jabba is a heaviest guy in the starwars world
#
# ### Exercise
#
# Visualize a Scatterplot of mass vs BMI

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')

starwars_clean = starwars[starwars['mass'] < 500].dropna(subset=['mass', 'height']).copy()

starwars_clean['BMI'] = starwars_clean['mass'] / ((starwars_clean['height'] / 100) ** 2)

plt.figure(figsize=(8, 5))
sns.scatterplot(x='mass', y='BMI', data=starwars_clean)
plt.title('Mass vs BMI (Filtered & Secure Mode)')
plt.show()

# %% [markdown]
# ### Exercise
#
# Visualize a Scatterplot of mass vs BMI with the outlier removed

# %%
#your code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')

starwars['BMI'] = starwars['mass'] / ((starwars['height'] / 100) ** 2)

starwars_filtered = starwars[starwars['mass'] < 500]
plt.figure(figsize=(10, 6))
sns.scatterplot(x='mass', y='BMI', data=starwars_filtered, color='green')
plt.title('Scatterplot: Mass vs BMI (Outlier Removed)')
plt.xlabel('Mass (kg)')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# ## Histogram
#
# Histogram is very useful to visualize distributions of continuous data based on raw frequencies

# %%
df['height'].plot(kind='hist');

# %% [markdown]
# ## Density
#
# Density plots help in visualizing the actual distribution of a column

# %%
df['height'].plot(kind='density');

# %% [markdown]
# ### Exercise
#
# Visualize a histogram and density plot for the `mass` column

# %%
#your code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')

plt.figure(figsize=(10, 6))
sns.histplot(starwars['mass'].dropna(), kde=True, color='dodgerblue', bins=30)

plt.title('Histogram and Density Plot of Mass')
plt.xlabel('Mass (kg)')
plt.ylabel('Frequency / Density')
plt.show()

# %%
#your code here

# %% [markdown]
# ## Boxplot
#
# The boxplot compactly displays the distribution of a continuous variable. It visualises five summary statistics (the median, two hinges and two whiskers), and all "outlying" points individually.

# %%
df['height'].plot(kind='box');

# %% [markdown]
# ### Exercise
#
# Plot the boxplot for `mass`

# %%
#your code here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')

sns.boxplot(x=starwars['mass'].dropna(), color='lightcoral')
plt.title('Boxplot of Character Mass')
plt.xlabel('Mass (kg)')
plt.show()

# %% [markdown]
# Filter the dataframe to exclude rows with `mass` > 400 and plot a boxplot for `mass` again

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

starwars = pd.read_csv('data/pw_stats_01_star_wars.csv')

starwars_filtered = starwars[starwars['mass'] <= 400]

plt.figure(figsize=(10, 6))
sns.boxplot(x='mass', data=starwars_filtered, color='skyblue')
plt.title('Boxplot of Mass (Filtered: Mass <= 400)')
plt.xlabel('Mass (kg)')
plt.show()

# %% [markdown]
# # Congratulations!
#
# You've finished all the steps in our tutorial and now you are one step closer to the basics of data analysis with python and `pandas`.
#
# We learned how to summarize your data, how to subset and slice by rows and by columns, how to mutate it and plot it. The language we used to write the commands remind the language we normally use when talk about data. With little practise you'll soon be able to deliver meaningful conclusions for making decisions.
#
# Good luck with the rest of the exercises and we are looking forward to discuss with you the beauty of Statistics during the course!
