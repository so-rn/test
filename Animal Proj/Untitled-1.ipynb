# %%
class Animal : 
    def __init__(self, name, color) :
        self.name = name 
        self.color = color
    def introduce(self) :
       print(f" Anima name :  {self.name} Color: {self.color}")
       
from animal import Animal
class Bird(Animal) :
    def __init__(self, name, color,melody, wings, can_fly) :
        super().__init__(name, color)
        self.wings = wings
        self.melody = melody
    def fly(self) :
        print(f"{self.name} is flying with {self.wings} wings and singing {self.melody}") 
    def sing(self) :
        print((self.melody + " ")*3)
        
from animal import Animal
class Fish(Animal) :
    def __init__(self, name, color,speed, habitat, can_swim) :
        super().__init__(name, color)
        self.speed = speed
    def swim(self) :
        print(f"{self.name} is swimming at , {self.color} fish , is swimm at {self.speed} km/h in )")
        
class Owl(Bird):
    def __init__(self, name, color, wings, melody, degree):
        super().__init__(name, color, wings, melody)
        self.degree = degree

    def neck_twist(self):
        print(f"{self.name} is doing a {self.degree} degree neck twist.")

class Woodpecker(Bird):
    def __init__(self, name, color, wings, melody, strength):
        super().__init__(name, color, wings, melody)
        self.strength = strength

    def make_hole(self):
        print("Tuk " * self.strength)
        
class Salmon(Fish):
    def swim(self):
        super().swim()
        print("...and it's swimming against the current!")

class Shark(Fish):
    def bite(self):
        print("hjhjh hjhjj hjhjjhjhj")
